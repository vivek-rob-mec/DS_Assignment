# %%
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
"""
1) By inheriting from Exception, a custom class becomes a proper exception type, aligning with Python's exception hierarchy.
   This ensures that it can be correctly caught and handled using try...except blocks.
2) If a custom class doesn't inherit from Exception (or a subclass), it won't be recognized as an exception,
   and the standard exception handling mechanisms won't work.
3) Inheriting from Exception grants access to these built-in functionalities, allowing custom exceptions to
   carry error messages and be easily represented as strings.
"""
# Out:
# "\n1) By inheriting from Exception, a custom class becomes a proper exception type, aligning with Python's exception hierarchy. \n   This ensures that it can be correctly caught and handled using try...except blocks.\n2) If a custom class doesn't inherit from Exception (or a subclass), it won't be recognized as an exception, \n   and the standard exception handling mechanisms won't work.\n3) Inheriting from Exception grants access to these built-in functionalities, allowing custom exceptions to \n   carry error messages and be easily represented as strings.\n"

# %%
# Q2. Write a python program to print Python Exception Hierarchy.
import sys

def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)
print_exception_hierarchy(Exception)
# Out:
# Exception
#     ArithmeticError
#         FloatingPointError
#         OverflowError
#         ZeroDivisionError
#             DivisionByZero
#             DivisionUndefined
#         DecimalException
#             Clamped
#             Rounded
#                 Underflow
#                 Overflow
#             Inexact
#                 Underflow
#                 Overflow
#             Subnormal
#                 Underflow
#             DivisionByZero
#             FloatOperation
#             InvalidOperation
#                 ConversionSyntax
#                 DivisionImpossible
#                 DivisionUndefined
#                 InvalidContext
#     AssertionError
#     AttributeError
#         FrozenInstanceError
#     BufferError
#     EOFError
#         IncompleteReadError
#     ImportError
#         ModuleNotFoundError
#             PackageNotFoundError
#             PackageNotFoundError
#         ZipImportError
#     LookupError
#         IndexError
# ...

# %%
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
"""
 ArithmeticError:
        FloatingPointError
        OverflowError
        ZeroDivisionError
            DivisionByZero
            DivisionUndefined
        DecimalException
            Clamped
            Rounded
                Underflow
                Overflow
            Inexact
                Underflow
                Overflow
            Subnormal
                Underflow
            DivisionByZero
            FloatOperation
            InvalidOperation
                ConversionSyntax
                DivisionImpossible
                DivisionUndefined
                InvalidContext
1) OverflowError: Raised when a calculation exceeds the maximum limit for a numeric type.
2) ZeroDivisionError: Raised when division or modulo by zero takes place for all numeric types.
"""
try:
  result = 2 ** 1000000  # large power
except OverflowError:
  print("OverflowError: The calculation resulted in a value too large to be represented.")
print()
try:
  result = 10 / 0  # Attempting to divide by zero
  print(result)
except ZeroDivisionError:
  print("ZeroDivisionError: Division by zero is not allowed.")
# Out:
# ZeroDivisionError: Division by zero is not allowed.

# %%
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
"""
LookupError:
        IndexError
            AxisError
            OutOfBounds
        KeyError
            NoSuchKernel
            UnknownBackend
        CodecRegistryError
Occur when trying to access a non-existent key or index in a data structure like a list, tuple, or dictionary, encompassing IndexError and KeyError.
LookupError:  Raised when a lookup operation fails because the key or index is invalid
IndexError: Raised when trying to access an index that is out of range for a sequence
"""
# Out:
# '\nLookupError:\n        IndexError\n            AxisError\n            OutOfBounds\n        KeyError\n            NoSuchKernel\n            UnknownBackend\n        CodecRegistryError\nOccur when trying to access a non-existent key or index in a data structure like a list, tuple, or dictionary, encompassing IndexError and KeyError. \nLookupError:  Raised when a lookup operation fails because the key or index is invalid\nIndexError: Raised when trying to access an index that is out of range for a sequence\n'

# %%
# Q5. Explain ImportError. What is ModuleNotFoundError?
"""
ImportError: Occurs when an import statement fails
        ModuleNotFoundError
            PackageNotFoundError
            PackageNotFoundError
        ZipImportError
ModuleNotFoundError: raised specifically when a module or package that your code is trying to import cannot be found,
                     usually because it's not installed or the path is incorrect.
"""
# Out:
# "\nImportError: Occurs when an import statement fails\n        ModuleNotFoundError\n            PackageNotFoundError\n            PackageNotFoundError\n        ZipImportError\nModuleNotFoundError: raised specifically when a module or package that your code is trying to import cannot be found, \n                     usually because it's not installed or the path is incorrect.\n"

# %%
# Q6. List down some best practices for exception handling in python.
"""
1. Use Specific Exceptions
2. Implement Error Logging
3. Define Custom Exception Classes
4. Handle Exceptions Gracefully
5. Use Finally for Cleanup Tasks
"""
# Out:
# '\n1. Use Specific Exceptions\n2. Implement Error Logging\n3. Define Custom Exception Classes\n4. Handle Exceptions Gracefully\n5. Use Finally for Cleanup Tasks\n'
